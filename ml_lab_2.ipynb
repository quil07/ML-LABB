# %% [markdown]
# Creating A Dataframe

# %% [markdown]
# Creating a dataframe

# %%
import pandas as pd
data = {'apples':[3,2,1,0,1] , 'oranges':[0,3,7,2, None]}
df=pd.DataFrame(data)
df
# Out:
#    apples  oranges
# 0       3      0.0
# 1       2      3.0
# 2       1      7.0
# 3       0      2.0
# 4       1      NaN

# %% [markdown]
# creating a dataframe with series form

# %%
import pandas as pd
df=pd.DataFrame(data, index=['Dudu','kalu','pandu','monu','kanha'])
df
# Out:
#        apples  oranges
# Dudu        3      0.0
# kalu        2      3.0
# pandu       1      7.0
# monu        0      2.0
# kanha       1      NaN

# %% [markdown]
# pandas orient keyword column wise

# %%
data = {'col_1': [3,2,1,0] , 'col_2' : ['a','b','c','d']}
pd.DataFrame.from_dict(data, orient='index')
# Out:
#        0  1  2  3
# col_1  3  2  1  0
# col_2  a  b  c  d

# %% [markdown]
# Row wise

# %%
data = {'row_1': [3,2,1,0] , 'row_2' : ['a','b','c','d']}
pd.DataFrame.from_dict(data, orient='index')
# Out:
#        0  1  2  3
# row_1  3  2  1  0
# row_2  a  b  c  d

# %% [markdown]
# Both row and column

# %%
data = {'row_1': [3,2,1,0] , 'row_2' : ['a','b','c','d']}
pd.DataFrame.from_dict(data, orient='index',columns=['A','B','C','D'])
# Out:
#        A  B  C  D
# row_1  3  2  1  0
# row_2  a  b  c  d

# %% [markdown]
# reading dataset from csv file

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# String format

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
df
print (df.to_string())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# variable

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd
mydataset = {
    "calories" : [420.390,380, None],
    "duration":[50,40,45]
}
df=pd.DataFrame(mydataset)
print(df)
# Out:
#    calories  duration
# 0    420.39        50
# 1    380.00        40
# 2       NaN        45

# %%
import pandas as pd
Data= {
    "calories" : [420.390,380, None],
    "duration":[50,40,45]
}
df=pd.DataFrame(Data,index=["day1","day2","day3"])
print(df)
# Out:
#       calories  duration
# day1    420.39        50
# day2    380.00        40
# day3       NaN        45

# %%
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
new_df=df.dropna()
print(new_df.to_string())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
df.dropna(inplace=True)
print(df.to_string())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
df.fillna({"Calories":130},inplace=True)
print(df.to_string())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d'])
}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# Column addtion

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d'])
}
df=pd.DataFrame(d)
print("Adding new column by passing as series")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print("Adding new column using the existing columns in DataFrame")
df['four']=df['one']+df['three']
print(df)
# Out:
# Adding new column by passing as series
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding new column using the existing columns in DataFrame
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %% [markdown]
# column deletion

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d']),
    'three' : pd.Series([10,20,30],index=['a','b','c'])
}
df=pd.DataFrame(d)
print("Our dataframe is")
print(df)
#print using del function
print("Deleting the first column using DEL function")
del df['one']
print(df)
#using pop function
print("Deleting another column using POP function")
df.pop('two')
print(df)
# Out:
# Our dataframe is
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Deleting the first column using DEL function
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# Deleting another column using POP function
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %% [markdown]
# Slicing in dataframe

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d'])
}
df=pd.DataFrame(d)
print(df[2:4])
print(df[1:4])
print(df[2:3])
# Out:
#    one  two
# c  3.0    3
# d  NaN    4
#    one  two
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two
# c  3.0    3

# %% [markdown]
# Addtion of 2 row

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d'])
}
df=pd.DataFrame(d)
print(df)
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df = pd.concat([df, df2], ignore_index=True)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two    a    b
# 0  1.0  1.0  NaN  NaN
# 1  2.0  2.0  NaN  NaN
# 2  3.0  3.0  NaN  NaN
# 3  NaN  4.0  NaN  NaN
# 4  NaN  NaN  5.0  6.0
# 5  NaN  NaN  7.0  8.0

# %% [markdown]
# row deletion

# %%
import pandas as pd
d = {
    'one' : pd.Series([1,2,3],index=['a','b','c']),
    'two' : pd.Series([1,2,3,4],index=['a','b','c','d'])
}
df=pd.DataFrame(d)
print(df)
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df = pd.concat([df, df2], ignore_index=True)
print(df)
df=df.drop(0)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two    a    b
# 0  1.0  1.0  NaN  NaN
# 1  2.0  2.0  NaN  NaN
# 2  3.0  3.0  NaN  NaN
# 3  NaN  4.0  NaN  NaN
# 4  NaN  NaN  5.0  6.0
# 5  NaN  NaN  7.0  8.0
#    one  two    a    b
# 1  2.0  2.0  NaN  NaN
# 2  3.0  3.0  NaN  NaN
# 3  NaN  4.0  NaN  NaN
# 4  NaN  NaN  5.0  6.0
# 5  NaN  NaN  7.0  8.0

# %% [markdown]
# Reindexing

# %% [markdown]
# ### Creating DataFrame `df1`

# %%
import pandas as pd
import numpy as np

# Create df1 with 5 numeric values and index 'a1' to 'a5'
data1 = {
    'a': np.random.randint(10, 100, 5),
    'b': np.random.randint(10, 100, 5),
    'c': np.random.randint(10, 100, 5),
    'd': np.random.randint(10, 100, 5)
}
index1 = ['a1', 'a2', 'a3', 'a4', 'a5']
df1 = pd.DataFrame(data1, index=index1)

print("DataFrame df1:")
print(df1)
# Out:
# DataFrame df1:
#      a   b   c   d
# a1  67  51  85  57
# a2  92  81  52  28
# a3  48  42  51  11
# a4  57  61  31  77
# a5  99  41  58  35

# %% [markdown]
# ### Creating DataFrame `df2`

# %%
# Create df2 with different numeric values and index 'a1', 'a3', 'a4', 'a7', 'a8'
data2 = {
    'a': np.random.randint(100, 200, 5),
    'b': np.random.randint(100, 200, 5),
    'c': np.random.randint(100, 200, 5),
    'd': np.random.randint(100, 200, 5)
}
index2 = ['a1', 'a3', 'a4', 'a7', 'a8']
df2 = pd.DataFrame(data2, index=index2)

print("DataFrame df2:")
print(df2)
# Out:
# DataFrame df2:
#       a    b    c    d
# a1  130  173  142  196
# a3  107  159  133  165
# a4  157  185  122  182
# a7  176  188  179  170
# a8  154  181  103  155

# %% [markdown]
# ### Reindexing `df2`

# %%
# Define a new index for reindexing
new_index = ['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9']

# Reindex df2
# Elements in the new_index that are not in the original index of df2 will result in NaN.
# Existing elements will be reordered according to new_index.
reindexed_df2 = df2.reindex(new_index)

print("Reindexed DataFrame df2:")
print(reindexed_df2)

# Reindex df2 and fill NaN values with a default value (e.g., 0)
reindexed_df2_filled = df2.reindex(new_index, fill_value=0)

print("\nReindexed DataFrame df2 with fill_value=0:")
print(reindexed_df2_filled)
# Out:
# Reindexed DataFrame df2:
#         a      b      c      d
# a1  130.0  173.0  142.0  196.0
# a2    NaN    NaN    NaN    NaN
# a3  107.0  159.0  133.0  165.0
# a4  157.0  185.0  122.0  182.0
# a5    NaN    NaN    NaN    NaN
# a6    NaN    NaN    NaN    NaN
# a7  176.0  188.0  179.0  170.0
# a8  154.0  181.0  103.0  155.0
# a9    NaN    NaN    NaN    NaN
#
# Reindexed DataFrame df2 with fill_value=0:
#       a    b    c    d
# a1  130  173  142  196
# a2    0    0    0    0
# a3  107  159  133  165
# a4  157  185  122  182
# a5    0    0    0    0
# a6    0    0    0    0
# a7  176  188  179  170
# a8  154  181  103  155
# a9    0    0    0    0
