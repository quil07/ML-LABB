# %% [markdown]
# #we hvae to take the dataset and we do polynomial regression degree 1 to 4 and accuracy and and logistic regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("pol.csv")

# %% [markdown]
# #degree 1

# %%
poly1 = PolynomialFeatures(degree=1)
X_poly1 = poly1.fit_transform(X)

model1 = LogisticRegression()

median_y_poly = y.median()
y_classified_poly = (y > median_y_poly).astype(int)

model1.fit(X_poly1, y_classified_poly)

y_pred1 = model1.predict(X_poly1)
y_prob1 = model1.predict_proba(X_poly1)[:, 1]

accuracy1 = accuracy_score(y_classified_poly, y_pred1)
error1 = 1 - accuracy1
loss1 = log_loss(y_classified_poly, y_prob1)

print("Degree 1 Accuracy:", accuracy1)
print("Degree 1 Error:", error1)
print("Degree 1 Log Loss:", loss1)

X_sorted = np.sort(X, axis=0)
X_sorted_poly1 = poly1.transform(X_sorted)
y_curve1 = model1.predict_proba(X_sorted_poly1)[:, 1]

plt.figure()
plt.scatter(X, y)
plt.plot(X_sorted, y_curve1)
plt.xlabel("sales")
plt.ylabel("Probability")
plt.title("Logistic Regression (Degree 1)")
plt.show()
# Out:
# Degree 1 Accuracy: 0.6122448979591837
# Degree 1 Error: 0.3877551020408163
# Degree 1 Log Loss: 0.6902693738151011
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #degree 2

# %%
poly2 = PolynomialFeatures(degree=2)
X_poly2 = poly2.fit_transform(X)

model2 = LogisticRegression()

median_y_poly = y.median()
y_classified_poly = (y > median_y_poly).astype(int)

model2.fit(X_poly2, y_classified_poly)

y_pred2 = model2.predict(X_poly2)
y_prob2 = model2.predict_proba(X_poly2)[:, 1]

accuracy2 = accuracy_score(y_classified_poly, y_pred2)
error2 = 1 - accuracy2
loss2 = log_loss(y_classified_poly, y_prob2)

print("Degree 2 Accuracy:", accuracy2)
print("Degree 2 Error:", error2)
print("Degree 2 Log Loss:", loss2)

X_sorted_poly2 = poly2.transform(X_sorted)
y_curve2 = model2.predict_proba(X_sorted_poly2)[:, 1]

plt.figure()
plt.scatter(X, y)
plt.plot(X_sorted, y_curve2)
plt.xlabel("sales")
plt.ylabel("Probability")
plt.title("Logistic Regression (Degree 2)")
plt.show()
# Out:
# Degree 2 Accuracy: 0.9795918367346939
# Degree 2 Error: 0.020408163265306145
# Degree 2 Log Loss: 0.07000747903449345
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #degree 3

# %%
poly3 = PolynomialFeatures(degree=3)
X_poly3 = poly3.fit_transform(X)

model3 = LogisticRegression()

median_y_poly = y.median()
y_classified_poly = (y > median_y_poly).astype(int)

model3.fit(X_poly3, y_classified_poly)

y_pred3 = model3.predict(X_poly3)
y_prob3 = model3.predict_proba(X_poly3)[:, 1]

accuracy3 = accuracy_score(y_classified_poly, y_pred3)
error3 = 1 - accuracy3
loss3 = log_loss(y_classified_poly, y_prob3)

print("Degree 3 Accuracy:", accuracy3)
print("Degree 3 Error:", error3)
print("Degree 3 Log Loss:", loss3)

X_sorted_poly3 = poly3.transform(X_sorted)
y_curve3 = model3.predict_proba(X_sorted_poly3)[:, 1]

plt.figure()
plt.scatter(X, y)
plt.plot(X_sorted, y_curve3)
plt.xlabel("sales")
plt.ylabel("Probability")
plt.title("Logistic Regression (Degree 3)")
plt.show()
# Out:
# Degree 3 Accuracy: 0.9795918367346939
# Degree 3 Error: 0.020408163265306145
# Degree 3 Log Loss: 0.0682868778294532
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #degree 4

# %%
poly4 = PolynomialFeatures(degree=4)
X_poly4 = poly4.fit_transform(X)

model4 = LogisticRegression()

# Convert continuous y to binary for classification
median_y_poly = y.median()
y_classified_poly = (y > median_y_poly).astype(int)

model4.fit(X_poly4, y_classified_poly)

y_pred4 = model4.predict(X_poly4)
y_prob4 = model4.predict_proba(X_poly4)[:, 1]

accuracy4 = accuracy_score(y_classified_poly, y_pred4)
error4 = 1 - accuracy4
loss4 = log_loss(y_classified_poly, y_prob4)

print("Degree 4 Accuracy:", accuracy4)
print("Degree 4 Error:", error4)
print("Degree 4 Log Loss:", loss4)

X_sorted_poly4 = poly4.transform(X_sorted)
y_curve4 = model4.predict_proba(X_sorted_poly4)[:, 1]

plt.figure()
plt.scatter(X, y)
plt.plot(X_sorted, y_curve4)
plt.xlabel("sales")
plt.ylabel("Probability")
plt.title("Logistic Regression (Degree 4)")
plt.show()
# Out:
# Degree 4 Accuracy: 0.9591836734693877
# Degree 4 Error: 0.04081632653061229
# Degree 4 Log Loss: 0.0467490511279928
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #Logistic regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = pd.read_csv("loan.csv")

# %%
model = LogisticRegression()

median_y = y.median()
y_classified = (y > median_y).astype(int)

model.fit(X, y_classified)

y_pred = model.predict(X)
accuracy = accuracy_score(y_classified, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6122448979591837

# %%
accuracy = accuracy_score(y_classified, y_pred)
classification_error = 1 - accuracy

print("Accuracy:", accuracy)
print("Classification Error:", classification_error)
# Out:
# Accuracy: 0.6122448979591837
# Classification Error: 0.3877551020408163

# %%
from sklearn.metrics import log_loss

y_prob_for_logloss = model.predict_proba(X)[:, 1]

error_log_loss = log_loss(y_classified, y_prob_for_logloss)
print("Log Loss Error:", error_log_loss)
# Out:
# Log Loss Error: 0.6902693046157721

# %%
X_sorted = np.sort(X, axis=0)
y_prob_sorted = model.predict_proba(X_sorted)[:, 1]

plt.figure()
plt.scatter(X, y)
plt.plot(X_sorted, y_prob_sorted)
plt.xlabel("X")
plt.ylabel("Probability")
plt.title("Logistic Regression with Error")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
